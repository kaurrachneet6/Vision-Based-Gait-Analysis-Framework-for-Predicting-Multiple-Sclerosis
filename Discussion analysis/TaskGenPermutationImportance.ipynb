# %%
#Mounting a google drive 
from google.colab import drive
drive.mount("/content/drive/", force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('drive/MyDrive/GVS/demo_repo')

# %%
import os
os.getcwd()
# Out:
# '/content/drive/MyDrive/GVS/demo_repo'

# %%
# !pip install pyitlib
# !pip install skorch
# Out:
# ...
#   Created wheel for pyitlib: filename=pyitlib-0.2.2-py3-none-any.whl size=28502 sha256=9f91206b813a6d9fec64fc09c310ddd205eb090523516fdea4b4ddb0baab54ba
#   Stored in directory: /root/.cache/pip/wheels/14/96/d6/86e32d66e5bb0440dc344e75849266b2bf2939520672e33e4e
# Successfully built pyitlib
# ...
#      |████████████████████████████████| 128 kB 5.0 MB/s
# ...

# %%
# !python TaskGen_PermutationImportance.py config_files/perm_imp_configs/config_template_task_gen_perm_imp_msresnet.json
# Out:
# Streaming output truncated to the last 5000 lines.
# <Figure size 640x480 with 2 Axes>
#
# Evaluation time:  37.87832808494568
# Stride-based model performance (Macro):  0.7608267716535433 0.767862822630656 0.7603111297890415 0.7606232249855719 0.9110734945462746
# Stride-based model performance (Micro):  0.7608267716535433 0.7608267716535433 0.7608267716535433 0.7608267716535433 None
# Stride-based model performance (Weighted):  0.7608267716535433 0.7694137256569217 0.7608267716535433 0.7617021822166797 0.911398207184082
# Stride-based model performance (Class-wise):  0.7608267716535433 [0.85015291 0.67336683 0.78006873] [0.79202279 0.80722892 0.68168168] [0.820059   0.73424658 0.7275641 ] None
# Best model:  <class 'skorch.net.NeuralNet'>[initialized](
#   module_=MSResNet(
#     (conv1): Conv1d(36, 64, kernel_size=(2,), stride=(1,), padding=(5,), bias=False)
#     (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import numpy
numpy.mean([0.5, 0.8333333333333334, 0.5, 0.8571428571428571, 0.5714285714285714])
# Out:
# 0.6523809523809524

# %%
import sys
sys.stdout.close()
sys.stdout=stdoutOrigin
# Out:
# Exception in callback BaseAsyncIOLoop._handle_events(17, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(17, 1)>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 451, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.7/dist-packages/zmq/eventloop/zmqstream.py", line 434, in _run_callback
#     callback(*args, **kwargs)
# ...
