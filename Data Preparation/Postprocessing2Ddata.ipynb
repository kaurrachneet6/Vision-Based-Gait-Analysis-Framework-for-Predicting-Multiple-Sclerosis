# %% [markdown]
# # Gait Video Study
# ### Postprocessing the created 2D keypoints (via OpenPose) for lower body and feet

# %%
import numpy as np
import cv2
import os
import glob
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML

# %%
path = 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\'

#Configuration for which to run the code for 
cohorts = ['\\HOA', '\\MS', '\\PD', '\\ExtraHOA']
trials = ['\\beam_walking', '\\walking']
cameras = ['\\feet\\', '\\lower_body\\']

#Dimensions of the image 
w = 800
h = 448

# %% [markdown]
# ### Utility functions

# %%
#The left hip marker must have x-coordinate values greater than right hip marker
def check_left_right_swap_needed(coords):
    global count #Telling the function that we are going to use global variable count and not the default local variable
    mid_hip_x = coords.loc[8, 'x']
    left_hip_x = coords.loc[12, 'x']
    right_hip_x = coords.loc[9, 'x']
    #If the left hip marker do not have x-coordinate values greater than right hip marker, a swap is needed
    if ((left_hip_x<mid_hip_x) & (right_hip_x>mid_hip_x)): 
        swap_needed = True
        count+=1
    else:
        swap_needed = False
    return swap_needed

# %%
def left_right_swap(coords):
    data_frame = pd.DataFrame()
#     print ('coords', coords[1:])
    if (check_left_right_swap_needed(coords)):
#         print (coords[1:])
#         print ('Left-right swap required!')
        data_frame=pd.DataFrame(coords[1:].values, index = order_swapped, columns = ['x', 'y', 'confidence'])
    else:
        data_frame=pd.DataFrame(coords[1:].values, index = order, columns = ['x', 'y', 'confidence'])
    data_frame = data_frame.reindex(order)
#     print (data_frame)
# print ('swapped df', data_frame, frame_path+video+'\\processed2d\\'+frame.split('\\')[-1][:-3]+'csv')
    return data_frame

# %%
def rename(dataframe):
    dataframe['cohort'][dataframe.cohort=='\\ExtraHOA'] = 'HOA'
    dataframe['cohort'][dataframe.cohort=='\\HOA'] = 'HOA'
    dataframe['cohort'][dataframe.cohort=='\\MS'] = 'MS'
    dataframe['cohort'][dataframe.cohort=='\\PD'] = 'PD'
    dataframe['trial'][dataframe.trial=='\\beam_walking'] = 'BW'
    dataframe['trial'][dataframe.trial=='\\walking'] = 'W'

# %%
#To check if the particular marker is not missing/is available in the frame 
def marker_available(coordinate_name, frame_path):
    frame_csv = pd.read_csv(frame_path, index_col = 0)
#     print (frame_csv)
    missing = (frame_csv.loc[coordinate_name].x==0) & (frame_csv.loc[coordinate_name].y==0) #Marker is missing in the frame
#     print ('Bool missing', not(missing))
    fill_list = list(frame_csv.loc[coordinate_name].values)
#     print ('Fill up values', fill_list)
    return not(missing), fill_list

# %%
#Create the temporary interpolation dataframe for interpolation for a particular marker in current frame
def create_missing_value_fillup_df(sorted_frames, idx, marker_name):
    seq_travelled = []  
    forward_idx, backward_idx, forward_count, backward_count = 1, 1, 0, 0
    #3 forward and 3 backward coordinates and 1 current coordinate as rows 
    #4 time, x, y, and confidence score as columns 
    interpolation_df = pd.DataFrame(np.zeros([2*num_coords_each_side+1, 4])*np.nan)
#     print ('Initial Interpolate DF:', interpolation_df)
    while (forward_count<3):
        forward_frame = sorted_frames[idx+forward_idx]
#         print ('forward frame', forward_frame)
        available, fill_list = marker_available(marker_name, forward_frame)
#         print ('Availability', available)
        if available:
#             print ('forward frame', forward_frame)
            forward_count+=1
            seq_travelled.append(forward_idx)
            interpolation_df.iloc[num_coords_each_side+forward_count] = [forward_idx]+fill_list 
            #Fill in indices 4, 5, 6
        forward_idx+=1
        
    while (backward_count<3):
        backward_frame = sorted_frames[idx-backward_idx]
#         print ('backward frame', backward_frame)
        available, fill_list = marker_available(marker_name, backward_frame)
        if available:
#             print ('backward frame', backward_frame)
            seq_travelled.append(backward_idx)
            interpolation_df.iloc[2-backward_count] = [-1*backward_idx]+fill_list #Fill in indices 0, 1, 2
            backward_count+=1
        backward_idx+=1
    interpolation_df.columns = ['time', 'x', 'y', 'conf']
    #Setting time 0 for current frame w.r.t. forward having positive time and backward frames having negative time
    interpolation_df.iloc[3].time = 0 #Row 3 is for current frame and column 0 is for time index 
#     print ('Interpolate DF: ', interpolation_df)
    return interpolation_df, seq_travelled

# %%
#For missing value treatment:
#1. Keep a threshold i.e. if more than 8 out of 12 coordinates are missing 
#(i.e. more than or equal to 75% of coordinates are missing), then ignore that frame 
#2. For a marker missing from the current frame, we are using interpolation with 3 nearest frames with the 
#marker non-missing in the forward and backward direction from the frames and keep time for these frames as part of 
#the interpolation process and use quadratic interpolation 
def missing_value_treatment(sorted_frames, idx, marker_name):
    #Consecutive no. of frames travelled in the sequence to fill up the current frame
    interpolate_df, seq_travelled = create_missing_value_fillup_df(sorted_frames, idx, marker_name)
    #Fill the particular marker in current frame using interpolation wrt time 
    #Set the time column as index of this dataframe 
    interpolate_df['time']-=interpolate_df['time'][0]
    interpolate_df.set_index('time')
    #Quadratic will automatically use the index values as the corresponding time 
    #Hence this a index aware interpolation 
    interpolate_df.interpolate(method = 'quadratic', inplace = True)
    #Extract the row at the 3rd index filled in using interpolation 
    #and set up the missing value and save as new csv when all missing markers 
    #are done filling for the current frame 
    interpolate_df.reset_index()
    #                             print ('Filled interpolate DF:', interpolate_df)
    #Not retaining the time we had used in interpolation step
    return interpolate_df.iloc[3].values[1:], seq_travelled

# %% [markdown]
# ## Front camera (lower body view): Left-right swap and missing value treatment
# ### Left-right swap if needed

# %%
#12 required coordinates for lower body indices + middle hip for swapping left/right if needed 
lower_body_indices = list(range(8, 15)) + list(range(19, 25))
print (len(lower_body_indices))
order = ['right hip', 'right knee', 'right ankle', 'left hip', 'left knee', 'left ankle', 'left toe 1', 'left toe 2', \
         'left heel', 'right toe 1', 'right toe 2', 'right heel']
order_swapped = ['left hip', 'left knee', 'left ankle', 'right hip', 'right knee', 'right ankle', 'right toe 1', 'right toe 2', \
         'right heel', 'left toe 1', 'left toe 2', 'left heel']
# Out:
# 13

# %%
#Left-right swap over all subjects and trials for lower-body extracted coordinates 
left_right_count_df = pd.DataFrame(columns = ['cohort', 'trial', 'video', 'count_left_right_swaps', 'count_total_frames'])
global count 
for cohort in cohorts:
    for trial in trials:
        for camera in cameras[1:]: #Front look camera only
            frame_path = path+cohort+trial+camera #Path to save the frames to 
            if (os.path.exists(frame_path)):
                videos = os.listdir(frame_path)
#             print (len(videos))
                for video in videos:
                    if not os.path.exists(frame_path+video+'\\processed2d'):
                        os.makedirs(frame_path+video+'\\processed2d')
                    frames = glob.glob(frame_path+video+'\\*.jpg')
                    count = 0 #Count of left-right swapped frames 
                    total_frames = 0 #Count of total frames 
                    for frame in frames:
    #                     print (frame)
                        csv_path = frame_path+video+'\\processed2d\\'+frame.split('\\')[-1][:-3]+'csv'
                        if not os.path.exists(csv_path):
                            try:
                                total_frames+=1
                                frame_csv = pd.read_csv(frame[:-3]+'csv', index_col = None)
                                coords = frame_csv.iloc[lower_body_indices][['x', 'y', 'confidence']]
                                data_frame = left_right_swap(coords)
                                data_frame.to_csv(csv_path)
                            except Exception as e:
                                print (e)
                    left_right_count_df.loc[len(left_right_count_df)] = [cohort, trial, video, count, total_frames]
left_right_count_df.to_csv(path+'left_right_count_lower_body_df.csv')

# %% [markdown]
# ### Missing value imputation

# %%
#Missing value treatment over all subjects and trials for lower-body extracted coordinates 
stats_cols = ['cohort', 'trial', 'video', 'count_missing0', 'count_missing1', \
                         'count_missing2', 'count_missing3', 'count_missing4', 'count_missing5', \
                         'count_missing6', 'count_missing7', 'count_missing8', \
                         'count_missing_greater8', 'count_total_frames']

cols_seq_travelled_df = ['cohort', 'trial', 'video', 'frame', 'missed marker', 'forward1', 'forward2', 'forward3', \
                        'backward1', 'backward2', 'backward3']
missing_value_lower_body_stats = pd.DataFrame(columns = stats_cols)
#Use 3 forward and backward coordinates to fill up the current coordinate 
num_coords_each_side = 3 
#Dataframe for store stats of consecutive frames explored to get non-missing values for the marker of frame of video
seq_travelled_dataframe = pd.DataFrame(columns = cols_seq_travelled_df)

# %%
for cohort in cohorts:
    for trial in trials:
        frame_path = path+cohort+trial+'\\lower_body\\'
        if (os.path.exists(frame_path)):
            videos = os.listdir(frame_path)
            for video in videos:
                csv_path = frame_path+video+'\\processed2d'
                frames = glob.glob(csv_path+'\\*.csv')
                sorted_frames = sorted(frames,  key=lambda name: int(name.split('\\')[-1][:-4]))
                counts_missing_frames = [0]*10 #Count of missing 0 markers to missing > 8 markers 
                for idx, frame in enumerate(sorted_frames):
    #                 print ('Current frame: ', frame)
                    try:
                        frame_csv = pd.read_csv(frame, index_col = 0)
    #                     print (frame_csv)
                        missing = frame_csv[(frame_csv.x==0) & (frame_csv.y==0)] #Missing rows/keypoints in the frame
    #                     print (missing) 
                        len_missing = len(missing)
                        if (len_missing ==0): #No missing values, just update the stats 
                            counts_missing_frames[len_missing]+=1
                        #If more than or equal to 75% of coordinates are missing, remove the frame
                        elif (len_missing>8): 
                            print(frame, " removed (>8 missing coordinates)!")
                            os.remove(frame)
                            counts_missing_frames[9]+=1
                        else:
                            counts_missing_frames[len_missing]+=1
                            for i in range(len_missing):
                                marker = missing.iloc[i]
    #                             print ('Missing marker name', marker.name)
                                frame_csv.loc[marker.name], seq_travelled = missing_value_treatment(sorted_frames, idx, marker.name)
                                #Fill in the seq_travelled_dataframe with video, frame, missing marker, travelled 
                                seq_travelled_dataframe.loc[len(seq_travelled_dataframe)]= [cohort, trial, video, frame.split('\\')[-1], \
                                                                                            marker.name] + seq_travelled   
                            frame_csv.to_csv(frame)
                    except Exception as e:
                        print ('Exception!', e)
                #In each video for each cohort, trial, how many out of total frames with missing 
                #no marker, missing 1 marker, missing 2 markers, ..., missing more than 8 markers hence deleted
                missing_value_lower_body_stats.loc[len(missing_value_lower_body_stats)] = [cohort, trial, video] + \
                counts_missing_frames + [len(frames)]
            print (video, 'DONE!')
missing_value_lower_body_stats.to_csv(path+'missing_value_lower_body_stats.csv')  
seq_travelled_dataframe.to_csv(path+'missing_values_seq_travelled_dataframe_lower_body_stats.csv')
# Out:
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\228.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\228.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\228.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\418.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\490.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\491.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\528.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\565.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\617.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\617.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\617.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\617.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\617.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\617.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\617.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\632.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\632.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\632.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\632.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\632.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\632.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\632.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\632.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\632.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\632.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\632.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\632.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\632.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\1461.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\1461.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\1461.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\1497.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\1670.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\1671.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim\processed2d\1671.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T1_1_Trim\\processed2d\\1671.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\0.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\1.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\2.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\3.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\3.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\3.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\3.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\3.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\6.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\9.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\10.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\10.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\30.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\340.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\340.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\340.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\340.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\340.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\794.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\794.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\794.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\794.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\794.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\794.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\794.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\794.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\794.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\794.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\794.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\803.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\810.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\810.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\810.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\982.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\982.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\1002.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\1002.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\lower_body\\InkedGVS_406_W_T2_1_Trim\\processed2d\\1002.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\1113.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim\processed2d\1169.csv  removed (>8 missing coordinates)!

# %% [markdown]
# #### Check

# %%
#Check that there are no left-right swaps or missing values left now for lower body frames 
count_missing, count_swap = 0, 0
for cohort in cohorts:
    for trial in trials:
        frame_path = path+cohort+trial+'\\lower_body\\'
        videos = os.listdir(frame_path)
        for video in videos:
            csv_path = frame_path+video+'\\processed2d'
            frames = glob.glob(csv_path+'\\*.csv')
            for frame in enumerate(sorted_frames):
                try:
                    frame_csv = pd.read_csv(frame, index_col = 0)
                    missing = frame_csv[(frame_csv.x==0) & (frame_csv.y==0)] #Missing rows/keypoints in the frame
                    len_missing = len(missing)
                    if (len_missing !=0): #No missing values, just update the stats 
                        print ('Missing left', frame)
                        count_missing+=1
                    #If the left hip marker do not have x-coordinate values greater than right hip marker, a swap is needed
                    if (frame_csv.loc['left_hip'].x<frame_csv.loc['right_hip'].x)
                        print ('Swap left', frame)
                        count_swap+=1
print ('Missing values left in lower body are:', count_missing)
print ('Swaps needed left in lower body are:', count_swap)

# %% [markdown]
# ### Statistics of left-right swaps

# %%
left_right_swaps_stats_df = pd.read_csv(path+'left_right_count_lower_body_df.csv', index_col = 0)
left_right_swaps_stats_df['proportion_swaps (in %)'] = 100*left_right_swaps_stats_df['count_left_right_swaps']/left_right_swaps_stats_df['count_total_frames']
rename(left_right_swaps_stats_df) #Renaming the cohort and trial 
left_right_swaps_stats_df

# %%
#Boxplot
plt.figure(figsize = (25, 6))
ax = sns.boxplot(y = 'value', x = 'feature_name' , hue = 'Label', data=new_regressN_df[new_regressN_df['TrialID']==2], orient = 'v', 
            linewidth=2.5, palette="Set3", showfliers=False, width=0.8)

# ax = sns.swarmplot(y = 'value', x = 'feature_name' , hue = 'Label', data=new_regressN_df[new_regressN_df['TrialID']==2],
#                    dodge = True, palette="Set2")
handles, _ = ax.get_legend_handles_labels()
sns.despine(offset=0)
handles, _ = ax.get_legend_handles_labels()
ax.legend(handles, ['HOA', 'PwMS'], loc = 'best')
plt.ylabel(r"Normalized values")
plt.xlabel('')
plt.xticks(list(range(0, 18)), feature_display_names)
plt.title('Multiple regression-based normalized gait data')
plt.ylim([0,1])
# plt.savefig(path + '..//viz//viz_regressN_swarm_trialWT.png', dpi = 250) #Use Box plot here 
plt.savefig(path + '..//viz//viz_regressN_trialWT.png', dpi = 250) #Use Swarmplot here 
plt.show()

# %%
#Statistics of left right swaps for the paper
print ('Mean swaps')
display(left_right_swaps_stats_df.groupby(['cohort', 'trial']).mean())
print ('Standard deviation of swaps')
display(left_right_swaps_stats_df.groupby(['cohort', 'trial']).std())

# %% [markdown]
# ### Statistics for missing value imputation for lower body OpenPose markers

# %% [markdown]
# ## Side camera (feet view)
# ### Retaining only coordinates with confidence score above a threshold (max. 8: 2 ankles, 4 toes and 2 heels)

# %%
#8 required coordinates for feet - ankle, toes and heel
#Coordinates 11, 14 for ankles and 19-24 for toes and heels 
feet_indices = [11, 14] + list(range(19, 25))
print (len(feet_indices))
order_feet = ['right ankle', 'left ankle', 'left toe 1', 'left toe 2', 'left heel', 'right toe 1', 'right toe 2', \
         'right heel']

#All the coordinates detected with probability <0.2 are set to 0 hence nullified 
threshold = 0.2
# Out:
# 8

# %%
def retain_feet_markers(coords, threshold):
    data_frame=pd.DataFrame(coords.values, index = order_feet, columns = ['x', 'y', 'confidence'])
    data_frame[data_frame['confidence']<threshold] = 0
    return data_frame

# %%
#Extract only ankles, toes and heels 
#Retain only the markers with confidence score higher than a set threshold (0.2)
#Do not fill any missing values 
for cohort in cohorts:
    for trial in trials:
        frame_path = path+cohort+trial+'\\feet\\' #Path to save the frames to 
        if (os.path.exists(frame_path)):
            videos = os.listdir(frame_path)
#             print (len(videos))
            for video in videos:
                if not os.path.exists(frame_path+video+'\\processed2d'):
                    os.makedirs(frame_path+video+'\\processed2d')
                frames = glob.glob(frame_path+video+'\\*.jpg')
                for frame in frames:
#                     print (frame)
                    csv_path = frame_path+video+'\\processed2d\\'+frame.split('\\')[-1][:-3]+'csv'
                    if not os.path.exists(csv_path):
                        try:
                            frame_csv = pd.read_csv(frame[:-3]+'csv', index_col = None)
                            coords = frame_csv.iloc[feet_indices][['x', 'y', 'confidence']]
                            data_frame = retain_feet_markers(coords, threshold)
                            data_frame.to_csv(csv_path)
                        except Exception as e:
                            print (e)
                print (video, 'for feet done!')
# Out:
# InkedGVS_212_T_T1_0_Trim for feet done!
# InkedGVS_212_T_T2_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\1497.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\1497.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\385.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\385.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\425.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\425.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\427.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\427.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\428.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\428.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\441.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\441.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\470.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\470.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\484.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\484.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\528.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\528.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\575.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\575.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\614.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\614.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim\883.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T1_0_Trim\\883.csv'
# InkedGVS_213_T_T1_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T2_0_Trim\705.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T2_0_Trim\\705.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T2_0_Trim\79.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T2_0_Trim\\79.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_213_T_T2_0_Trim\948.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_213_T_T2_0_Trim\\948.csv'
# InkedGVS_213_T_T2_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\100.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\100.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1000.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1000.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1003.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1003.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\101.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\101.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1013.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1013.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1014.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1014.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1016.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1016.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1017.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1017.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\102.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\102.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1021.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1021.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1022.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1022.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1026.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1026.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1027.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1027.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1028.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1028.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1029.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1029.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\103.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\103.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1030.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1030.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1032.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1032.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1033.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1033.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1034.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1034.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1037.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1037.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1038.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1038.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1042.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1042.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1043.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1043.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1044.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1044.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1047.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1047.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1050.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1050.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1051.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1051.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1052.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1052.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1055.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1055.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1056.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1056.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1057.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1057.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1058.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1058.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1061.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1061.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1062.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1062.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1064.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1064.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1067.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1067.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1073.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1073.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1075.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1075.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1076.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1076.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1077.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1077.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1078.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1078.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1082.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1082.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1084.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1084.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1085.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1085.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1086.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1086.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1087.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1087.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1090.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1090.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1091.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1091.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1092.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1092.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1093.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1093.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1094.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1094.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1099.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1099.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1101.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1101.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1102.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1102.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1105.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1105.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1107.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1107.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1109.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1109.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1110.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1110.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1111.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1111.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1112.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1112.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1113.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1113.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1114.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1114.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1115.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1115.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1119.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1119.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1131.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1131.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\114.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\114.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1141.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1141.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1142.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1142.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1143.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1143.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1144.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1144.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1145.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1145.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1149.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1149.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\115.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\115.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1150.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1150.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1151.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1151.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1158.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1158.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1159.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1159.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\116.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\116.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1167.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1167.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1168.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1168.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1169.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1169.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\117.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\117.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1170.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1170.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1171.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1171.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1172.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1172.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1177.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1177.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1178.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1178.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\118.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\118.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1181.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1181.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1183.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1183.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1186.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1186.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1187.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1187.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\119.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\119.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1190.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1190.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1191.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1191.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1192.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1192.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1194.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1194.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1195.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1195.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1197.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1197.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1198.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1198.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1199.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1199.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\120.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\120.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1200.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1200.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1201.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1201.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1204.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1204.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\121.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\121.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1213.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1213.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1214.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1214.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1215.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1215.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1216.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1216.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1218.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1218.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1219.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1219.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\122.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\122.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1220.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1220.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1221.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1221.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1222.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1222.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1223.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1223.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1224.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1224.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1225.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1225.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1226.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1226.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1229.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1229.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\123.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\123.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1230.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1230.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1233.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1233.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1234.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1234.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1235.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1235.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1238.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1238.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1243.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1243.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1249.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1249.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1251.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1251.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1252.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1252.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1255.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1255.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1256.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1256.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1257.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1257.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1258.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1258.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1261.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1261.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1268.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1268.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1270.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1270.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1271.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1271.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1272.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1272.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim\1273.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\HOA\\beam_walking\\feet\\InkedGVS_214_T_T2_0_Trim\\1273.csv'
# ...
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_406_T_T2_0_Trim\253.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_406_T_T2_0_Trim\\253.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_406_T_T2_0_Trim\32.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_406_T_T2_0_Trim\\32.csv'
# InkedGVS_406_T_T2_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_407_T_T1_0_Trim\1642.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_407_T_T1_0_Trim\\1642.csv'
# InkedGVS_407_T_T1_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_407_T_T2_0_Trim\1387.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_407_T_T2_0_Trim\\1387.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_407_T_T2_0_Trim\1389.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_407_T_T2_0_Trim\\1389.csv'
# InkedGVS_407_T_T2_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T1_0_Trim\1359.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T1_0_Trim\\1359.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T1_0_Trim\677.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T1_0_Trim\\677.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T1_0_Trim\810.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T1_0_Trim\\810.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T1_0_Trim\823.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T1_0_Trim\\823.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T1_0_Trim\824.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T1_0_Trim\\824.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T1_0_Trim\87.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T1_0_Trim\\87.csv'
# InkedGVS_408_T_T1_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\1018.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\1018.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\126.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\126.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\127.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\127.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\147.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\147.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\148.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\148.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\376.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\376.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\377.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\377.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\942.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\942.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim\971.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\beam_walking\\feet\\InkedGVS_408_T_T2_0_Trim\\971.csv'
# InkedGVS_408_T_T2_0_Trim for feet done!
# InkedGVS_410_T_T1_0_Trim for feet done!
# InkedGVS_410_T_T2_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_403_W_T2_0_Trim\135.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_403_W_T2_0_Trim\\135.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_403_W_T2_0_Trim\358.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_403_W_T2_0_Trim\\358.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_403_W_T2_0_Trim\78.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_403_W_T2_0_Trim\\78.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_403_W_T2_0_Trim\86.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_403_W_T2_0_Trim\\86.csv'
# InkedGVS_403_W_T2_0_Trim for feet done!
# InkedGVS_404_W_T1_0_Trim for feet done!
# InkedGVS_404_W_T2_0_Trim for feet done!
# InkedGVS_404_W_T3_0_Trim for feet done!
# InkedGVS_404_W_T4_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T1_0_Trim\1129.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T1_0_Trim\\1129.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T1_0_Trim\358.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T1_0_Trim\\358.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T1_0_Trim\360.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T1_0_Trim\\360.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T1_0_Trim\415.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T1_0_Trim\\415.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T1_0_Trim\578.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T1_0_Trim\\578.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T1_0_Trim\6.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T1_0_Trim\\6.csv'
# InkedGVS_406_W_T1_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\193.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\193.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\234.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\234.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\259.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\259.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\280.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\280.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\332.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\332.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\345.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\345.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\346.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\346.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\562.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\562.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\563.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\563.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\63.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\63.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\636.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\636.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\638.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\638.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\639.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\639.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\675.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\675.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\676.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\676.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\677.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\677.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\681.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\681.csv'
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim\785.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_406_W_T2_0_Trim\\785.csv'
# InkedGVS_406_W_T2_0_Trim for feet done!
# InkedGVS_407_W_T1_0_Trim for feet done!
# InkedGVS_407_W_T2_0_Trim for feet done!
# InkedGVS_408_W_T1_0_Trim for feet done!
# InkedGVS_408_W_T2_0_Trim for feet done!
# InkedGVS_410_W_T1_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_410_W_T2_0_Trim\76.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_410_W_T2_0_Trim\\76.csv'
# InkedGVS_410_W_T2_0_Trim for feet done!
# InkedGVS_411_W_T1_0_Trim_with_problem for feet done!
# InkedGVS_411_W_T2_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_411_W_T3_0_Trim\1478.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_411_W_T3_0_Trim\\1478.csv'
# InkedGVS_411_W_T3_0_Trim for feet done!
# [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\openpose_data\\PD\walking\feet\InkedGVS_411_W_T4_0_Trim\1215.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\\\PD\\walking\\feet\\InkedGVS_411_W_T4_0_Trim\\1215.csv'
# InkedGVS_411_W_T4_0_Trim for feet done!

# %% [markdown]
# #### Check

# %%
#Check that all feet videos have been retained correctly 
count_not_retained = 0
for cohort in cohorts:
    for trial in trials:
        frame_path = path+cohort+trial+'\\feet\\' #Path to save the frames to 
        if (os.path.exists(frame_path)):
            videos = os.listdir(frame_path)
#             print (len(videos))
            for video in videos:
                frames = glob.glob(frame_path+video+'\\processed2d\\*.csv')
                for frame in frames:
#                     print (frame)
                    try:
                        frame_csv = pd.read_csv(frame, index_col = None)
                        if (np.sum(frame_csv['confidence']<0.2.values)):
                            print ('feet not done frame', frame)
                            count_not_retained+=1
                    except Exception as e:
                        print (e)
print ('Not done count:', count_not_retained)

# %% [markdown]
# ### Statistics for retained feet coordinates

# %%
#For each feet view video of each cohort and trial, how many frames retained and how many frames had each coordinate
#(left ankle, right ankle etc.) retained after cleaning out of total frames available for that video 
feet_markers_retained = ['cohort', 'trial', 'video'] + order_feet
stats_feet_markers_retained = pd.DataFrame(columns = feet_markers_retained)
count_markers_retained = np.zeros(1, 8)

# %%
for cohort in cohorts:
    for trial in trials:
        frame_path = path+cohort+trial+'\\feet\\' #Path to save the frames to 
        if (os.path.exists(frame_path)):
            videos = os.listdir(frame_path)
#             print (len(videos))
            for video in videos:
                frames = glob.glob(frame_path+video+'\\processed2d\\*.csv')
                total_retained_frames = len(frames)
                for frame in frames:
#                     print (frame)
                    try:
                        frame_csv = pd.read_csv(frame, index_col = None)
                        count_markers_retained+=np.array([int(i) for i in frame_csv['confidence']!=0])
                    except Exception as e:
                        print (e)
                stats_feet_markers_retained.loc[len(stats_feet_markers_retained)] = [cohort]+[trial]+\
                [video]+count_markers_retained
stats_feet_markers_retained.to_csv(path+'stats_feet_markers_retained.csv')

# %% [markdown]
# #### Analysis on confidence scores of retained frames after processing to quantify the quality of application of OpenPose on our dataset for both lower_body and feet frames. The confidence score quantifies the probability of predicting each marker correctly using the algorithm

# %%
def analyse_openpose_confidence(order, frame_path, video):
    '''
    Function to compute the dataframe with confidence scores from all retained markers and frames 
    '''
    confidence_video = pd.DataFrame(columns = order)
    frames = glob.glob(frame_path+video+'\\processed2d\\*.csv')
    for frame in frames:
    #   print (frame)
        try:
            frame_csv = pd.read_csv(frame, index_col = 0)
#             print (frame_csv['confidence'])
            confidence_video.loc[len(confidence_video)] = frame_csv['confidence']
        except Exception as e:
            print (e) 
#     print ('Dataframe', stats_openpose_confidence)
    #Replacing zero confidence score with NaN since we only need stats over retained coordinates, hence those 
    #with confidence score > 0
    confidence_video.replace(0, value = np.nan, inplace = True) 
    return confidence_video

# %%
#Mean and standard deviation of confidence score for each marker of each video for each camera, trial and cohort 
#Note that we are computing the confidence score averages and standard deviations only over retained coordinates 
#i.e. if suppose left knee had a <0.2 confidence score in feet view and was thus deleted, we do not use that 
#deleted marker in this computation 
order = ['right hip', 'right knee', 'right ankle', 'left hip', 'left knee', 'left ankle', 'left toe 1', 'left toe 2', \
         'left heel', 'right toe 1', 'right toe 2', 'right heel']

confidence_openpose_columns = ['cohort', 'trial', 'camera', 'video'] + [x + '_mean' for x in order] +\
[x + '_std' for x in order]
stats_openpose_confidence = pd.DataFrame(columns = confidence_openpose_columns)

# %%
for cohort in cohorts:
    for trial in trials:
        for camera in cameras:
            frame_path = path+cohort+trial+camera #Path to save the frames to 
            if (os.path.exists(frame_path)):
                videos = os.listdir(frame_path)
    #             print (len(videos))
                for video in videos:
                    confidence_video = analyse_openpose_confidence(order, frame_path, video)
                    stats_openpose_confidence.loc[len(stats_openpose_confidence)] = [cohort]+[trial]+[camera]+[video]+\
                    list(confidence_video.mean().values)+list(confidence_video.std().values)
#                     display(stats_openpose_confidence)
                print (video, 'DONE!')
stats_openpose_confidence.columns = ['cohort', 'trial', 'camera', 'video'] + [x + '_mean' for x in order] +\
[x + '_std' for x in order]
stats_openpose_confidence.to_csv(path+'stats_openpose_confidence_scores.csv')
# Out:
# InkedGVS_219_T_T2_0_Trim DONE!
# InkedGVS_219_T_T2_1_Trim DONE!
# InkedGVS_219_W_T2_0_Trim DONE!
# InkedGVS_219_W_T2_1_Trim DONE!
# InkedGVS_323_T_T1_0_Trim DONE!
# InkedGVS_323_T_T1_1_Trim DONE!
# InkedGVS_323_W_T2_0_Trim DONE!
# InkedGVS_323_W_T2_1_Trim DONE!
# InkedGVS_410_T_T2_0_Trim DONE!
# No columns to parse from file
# No columns to parse from file
# InkedGVS_410_T_T2_1_Trim DONE!
# InkedGVS_411_W_T4_0_Trim DONE!
# InkedGVS_411_W_T4_1_Trim DONE!
# InkedGVS_124_W_T1_1_Trim DONE!

# %%
#Stats for openpose confidence scores 
stats_openpose_confidence = pd.read_csv(path+'stats_openpose_confidence_scores.csv', index_col = 0)
rename(stats_openpose_confidence)
print ('Mean over all videos in that cohort and trial of means and SDs over all frames for each video')
display(stats_openpose_confidence.groupby(['cohort', 'trial']).mean().T)
#Note that here mean = mean over all videos in that cohort and trial of mean over all frames of each video 
#= mean(mean)
#Standard deviation = mean over all videos in that cohort and trial of SD over all frames of each video 
#= mean(SD)
# Out:
# Mean over all videos in that cohort and trial of means and SDs over all frames for each video
# cohort                 HOA                  MS                  PD
# trial                   BW         W        BW         W        BW         W
# right hip_mean    0.381563  0.431077  0.447521  0.450482  0.380234  0.429963
# right knee_mean   0.645492  0.674083  0.687499  0.718793  0.587799  0.668739
# right ankle_mean  0.469933  0.565202  0.527126  0.567006  0.472648  0.585084
# left hip_mean     0.386260  0.446164  0.447302  0.458573  0.389198  0.448676
# left knee_mean    0.649378  0.682020  0.671717  0.719922  0.580710  0.673522
# left ankle_mean   0.459298  0.558744  0.504178  0.562030  0.459149  0.581653
# left toe 1_mean   0.411145  0.554102  0.436908  0.555598  0.411065  0.561096
# left toe 2_mean   0.424087  0.560018  0.449553  0.555536  0.422411  0.561145
# left heel_mean    0.337048  0.437387  0.376582  0.454760  0.328581  0.455766
# right toe 1_mean  0.411636  0.552070  0.463271  0.565674  0.419880  0.569214
# right toe 2_mean  0.408930  0.528598  0.453043  0.540949  0.411762  0.541110
# right heel_mean   0.345786  0.464656  0.390534  0.487522  0.345803  0.494601
# right hip_std     0.082427  0.066835  0.092077  0.087689  0.093492  0.087457
# right knee_std    0.110828  0.095215  0.113310  0.096480  0.136600  0.105357
# right ankle_std   0.104418  0.099610  0.102927  0.091356  0.111917  0.098194
# left hip_std      0.081166  0.067464  0.091788  0.085488  0.091322  0.088418
# left knee_std     0.113895  0.095324  0.123534  0.101373  0.134791  0.098546
# left ankle_std    0.107196  0.089569  0.115770  0.088431  0.122234  0.091694
# left toe 1_std    0.150876  0.110080  0.155436  0.104921  0.154714  0.112063
# left toe 2_std    0.139993  0.101387  0.144220  0.095347  0.145712  0.102847
# left heel_std     0.096535  0.080805  0.111494  0.080814  0.102292  0.080702
# right toe 1_std   0.138138  0.106957  0.134590  0.103858  0.143001  0.112802
# right toe 2_std   0.124055  0.094889  0.124128  0.091984  0.128116  0.100526
# right heel_std    0.102406  0.091722  0.106523  0.086240  0.106931  0.093759

# %%
#Boxplot
