# %% [markdown]
# ## Gait Video Study
# #### Postprocessing the created 3D keypoints (via intrinsic and extrinsic matrix) for lower body and feet and combining together both front and side view 3D coordinates to get the final combined coordinates. Further, scaling all average hip heights to a constant to normalize for subject heights in our dataset.
# References:
#
# http://personal.cityu.edu.hk/meachan/Online%20Anthropometry/Chapter2/Ch2-5.htm
# https://msis.jsc.nasa.gov/sections/section03.htm

# %%
import numpy as np
import cv2
import os
import glob
import matplotlib.pyplot as plt
import pandas as pd
import shutil
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, HTML

# %%
#Path for 3d data 
path_2d = 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\openpose_data\\' 
path = 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\3D_data\\' 
#Path to save the merged coordinates from both cameras 
frame_path_merged = 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\'

#Configuration for which to run the code for 
cohorts = ['\\HOA', '\\MS', '\\PD', '\\ExtraHOA']
trials = ['\\beam_walking', '\\walking']
cameras = ['\\feet\\', '\\lower_body\\']

#Dimensions of the image 
w = 800
h = 448

#Bounds for 3D coordinates 
x_min, y_min, z_min = 0.0001, 0.0001, 0.0001
x_max, y_max, z_max = 87, 310, 120

#Hard limits for coordinates, beyond which we delete the respective coordinate before adjusting for 
#z-coordinate or upper bounding for all coordinates 
#We upper bound the z- coordinate between 120 cm(~20 cm higher than the average American hip height) and 180 cm
#(which we assume as our hard upper limit for z-coordinate, beyond which, we assume that coordinate it 
#is recording is not correct, hence we delete that markers' recordings i.e. set x, y, z, confidence = 
#0, 0, 0, 0) to 120 cm. Further later on, to eliminate the size demographics from our datasets, we will 
#scale all coordinates to make sure that the hip height for each subject is same as the 
#average American hip height http://personal.cityu.edu.hk/meachan/Online%20Anthropometry/Chapter2/Ch2-5.htm
limit_x_min, limit_y_min, limit_z_min = -15, -50, -120
limit_x_max, limit_y_max, limit_z_max = 120, 400, 180

#Counts for sanity check after post processing 
x_coord_negative, y_coord_negative, z_coord_negative = 0, 0, 0
global sanity_x, sanity_y, sanity_z

#Order for the merged coordinates 
order = ['right hip', 'right knee', 'right ankle', 'left hip', 'left knee', 'left ankle', 'left toe 1', 'left toe 2', \
         'left heel', 'right toe 1', 'right toe 2', 'right heel']

#Constant hip height for hip height normalization across all subjects 
const_hip_height = 100 #in cm

# %% [markdown]
# ### Utility functions

# %%
def hard_limit(frame_csv):
    #Zero out all x, y, z, and confidence for coordinates that violate the 
    #hard constraints 
    hard_condition = (frame_csv.x>limit_x_max)|(frame_csv.y>limit_y_max)\
    |(frame_csv.z>limit_z_max)|(frame_csv.x<limit_x_min)|(frame_csv.y<limit_y_min)|\
    (frame_csv.z<limit_z_min)
    frame_csv[hard_condition] = 0
    return frame_csv

# %%
def shift_nonnegative(frame_csv):
    #If the minimum z-value is negative, hence a shift is needed 
    #Make sure to not shift the 0 z-coordinate for the markers that are missing 
    #(i.e. have x, y, z, confidence = 0, 0, 0, 0)
    if (frame_csv.x.min()<0): 
        frame_csv.x[frame_csv.confidence!=0]+=(-1*frame_csv.x.min() + x_min)
    if (frame_csv.y.min()<0): 
        frame_csv.y[frame_csv.confidence!=0]+=(-1*frame_csv.y.min() + y_min)
    if (frame_csv.z.min()<0): 
        frame_csv.z[frame_csv.confidence!=0]+=(-1*frame_csv.z.min() + z_min)
    return frame_csv

# %%
def upper_bound(frame_csv):
    #Upper bound the x, y, z coordinates if they exceed the max bounds 
    frame_csv.x[frame_csv.x>x_max] = x_max
    frame_csv.y[frame_csv.y>y_max] = y_max
    frame_csv.z[frame_csv.z>z_max] = z_max  
    return frame_csv

# %%
def sanity_check(frame_csv):
    #Sanity check to check if there are any x<0, or y<0 or z<0 that 
    #we may need to treat 
    global sanity_x, sanity_y, sanity_z
    if ((frame_csv.x<0).sum()>0 | (frame_csv.x>x_max+x_min).sum()>0):
        snaity_x+=1
        print ('x-coordinate sanity not satisfied for ', frame)
    if ((frame_csv.y<0).sum()>0 | (frame_csv.y>y_max+y_min).sum()>0):
        snaity_y+=1
        print ('y-coordinate sanity not satisfied for ', frame)
    if ((frame_csv.z<0).sum()>0 | (frame_csv.z>z_max+z_min).sum()>0):
        snaity_z+=1
        print ('z-coordinate sanity not satisfied for ', frame)

# %%
#To check if the particular marker is not missing/is available in the frame 
def marker_available(coordinate_name, frame_path):
    frame_csv = pd.read_csv(frame_path, index_col = 0)
#     print (frame_csv)
    missing = (frame_csv.loc[coordinate_name].x==0) & (frame_csv.loc[coordinate_name].y==0) & (frame_csv.loc[coordinate_name].z==0) #Marker is missing in the frame
#     print ('Bool missing', not(missing))
    fill_list = list(frame_csv.loc[coordinate_name].values)
#     print ('Fill up values', fill_list)
    return not(missing), fill_list

# %%
#Create the temporary interpolation dataframe for interpolation for a particular marker in current frame
def create_missing_value_fillup_df(sorted_frames, idx, marker_name):
    num_coords_each_side = 3 
    forward_idx, backward_idx, forward_count, backward_count = 1, 1, 0, 0
    #3 forward and 3 backward coordinates and 1 current coordinate as rows 
    #4 time, x, y, z and confidence score as columns 
    interpolation_df = pd.DataFrame(np.zeros([2*num_coords_each_side+1, 5])*np.nan)
#     print ('Initial Interpolate DF:', interpolation_df)
    while (forward_count<3):
        forward_frame = sorted_frames[idx+forward_idx]
#         print ('forward frame', forward_frame)
        available, fill_list = marker_available(marker_name, forward_frame)
#         print ('Availability', available)
        if available:
#             print ('forward frame', forward_frame)
            forward_count+=1
            interpolation_df.iloc[num_coords_each_side+forward_count] = [forward_idx]+fill_list 
            #Fill in indices 4, 5, 6
        forward_idx+=1
        
    while (backward_count<3):
        backward_frame = sorted_frames[idx-backward_idx]
#         print ('backward frame', backward_frame)
        available, fill_list = marker_available(marker_name, backward_frame)
        if available:
#             print ('backward frame', backward_frame)
            interpolation_df.iloc[2-backward_count] = [-1*backward_idx]+fill_list #Fill in indices 0, 1, 2
            backward_count+=1
        backward_idx+=1
    interpolation_df.columns = ['time', 'x', 'y', 'z', 'conf']
    #Setting time 0 for current frame w.r.t. forward having positive time and backward frames having negative time
    interpolation_df.iloc[3].time = 0 #Row 3 is for current frame and column 0 is for time index 
#     print ('Interpolate DF: ', interpolation_df)
    return interpolation_df

# %%
#For missing value treatment:
#1. Keep a threshold i.e. if more than 8 out of 12 coordinates are missing 
#(i.e. more than or equal to 75% of coordinates are missing), then ignore that frame 
#2. For a marker missing from the current frame, we are using interpolation with 3 nearest frames with the 
#marker non-missing in the forward and backward direction from the frames and keep time for these frames as part of 
#the interpolation process and use quadratic interpolation 
def missing_value_treatment(sorted_frames, idx, marker_name):
    #Consecutive no. of frames travelled in the sequence to fill up the current frame
    interpolate_df = create_missing_value_fillup_df(sorted_frames, idx, marker_name)
    #Fill the particular marker in current frame using interpolation wrt time 
    #Set the time column as index of this dataframe 
    interpolate_df['time']-=interpolate_df['time'][0]
    interpolate_df.set_index('time')
    #Quadratic will automatically use the index values as the corresponding time 
    #Hence this a index aware interpolation 
    interpolate_df.interpolate(method = 'quadratic', inplace = True)
    #Extract the row at the 3rd index filled in using interpolation 
    #and set up the missing value and save as new csv when all missing markers 
    #are done filling for the current frame 
    interpolate_df.reset_index()
    #                             print ('Filled interpolate DF:', interpolate_df)
    #Not retaining the time we had used in interpolation step
    return interpolate_df.iloc[3].values[1:]

# %% [markdown]
# ### Postprocessing for both front (lower body) and side camera (feet)

# %%
for cohort in cohorts:
    for trial in trials:
        for camera in cameras:
            frame_path = path+cohort+trial+camera #Path to save the frames to 
            if (os.path.exists(frame_path)):
                videos = os.listdir(frame_path)
#             print (len(videos))
                for video in videos:
                    if not os.path.exists(frame_path+video+'\\processed3d'):
                        os.makedirs(frame_path+video+'\\processed3d')
                    frames = glob.glob(frame_path+video+'\\*.csv')
                    for frame in frames:
    #                     print (frame)
                        csv_path = frame_path+video+'\\processed3d\\'+frame.split('\\')[-1]
                        if not os.path.exists(csv_path):
                            try:
                                frame_csv = pd.read_csv(frame, index_col = 0)
                                #To delete (convert x, y, z, confidence to 0, 0, 0, 0) the coordinates 
                                #which do not satisfy the hard limits and hence 
                                #are most probably not the coordinates for the subject in the frame
                                frame_csv = hard_limit(frame_csv)
                                #To shift up the z-coordinates (and sometime x, y-also)of the frame 
                                #if any z (and sometimes x, y also) is <0 
                                frame_csv = shift_nonnegative(frame_csv)
                                #To upper bound the x>width of the treadmill to the width 
                                # and y>length of the treadmill to the length 
                                frame_csv = upper_bound(frame_csv)
                                #Sanity check to check if there are any x<0, or y<0 or z<0 that 
                                #we may need to treat 
                                if ((frame_csv.x<0).sum()>0):
                                    x_coord_negative+=1
                                    print (frame)
                                if ((frame_csv.y<0).sum()>0):
                                    y_coord_negative+=1
                                    print (frame)
                                if ((frame_csv.z<0).sum()>0):
                                    z_coord_negative+=1
                                    print (frame)
#                                 print (frame_csv)
                                frame_csv.to_csv(csv_path)
                            except Exception as e:
                                print (e)
                    print (video, 'Done!')
print ('Count of negative x, y and z coordinates are:', x_coord_negative, y_coord_negative, z_coord_negative)
# Out:
# InkedGVS_212_T_T1_0_Trim Done!
# InkedGVS_212_T_T2_0_Trim Done!
# InkedGVS_213_T_T1_0_Trim Done!
# InkedGVS_213_T_T2_0_Trim Done!
# InkedGVS_214_T_T2_0_Trim Done!
# InkedGVS_215_T_T1_0_Trim Done!
# InkedGVS_215_T_T2_0_Trim Done!
# InkedGVS_216_T_T1_0_Trim Done!
# InkedGVS_216_T_T2_0_Trim Done!
# InkedGVS_310_T_T1_1_Trim Done!
# InkedGVS_310_T_T2_1_Trim Done!
# InkedGVS_311_T_T1_1_Trim Done!
# InkedGVS_311_T_T2_1_Trim Done!
# InkedGVS_312_T_T1_Trim Done!
# InkedGVS_312_T_T2_Trim Done!
# InkedGVS_314_T_T1_1_Trim Done!
# InkedGVS_314_T_T2_1_Trim Done!
# InkedGVS_318_T_T1_Trim Done!
# InkedGVS_318_T_T2_Trim Done!
# InkedGVS_320_T_T1_1_Trim Done!
# InkedGVS_320_T_T2_1_Trim Done!
# InkedGVS_321_T_T1_1_Trim Done!
# InkedGVS_321_T_T2_1_Trim Done!
# InkedGVS_323_T_T1_1_Trim Done!
# InkedGVS_310_W_T1_0_Trim Done!
# InkedGVS_310_W_T2_0_Trim Done!
# InkedGVS_311_W_T1_0_Trim Done!
# InkedGVS_311_W_T2_0_Trim Done!
# InkedGVS_313_W_T1_0_Trim Done!
# InkedGVS_313_W_T2_0_Trim Done!
# InkedGVS_314_W_T1_0_Trim Done!
# InkedGVS_314_W_T2_0_Trim Done!
# InkedGVS_320_W_T1_0_Trim Done!
# InkedGVS_320_W_T2_0_Trim Done!
# InkedGVS_321_W_T1_0_Trim Done!
# InkedGVS_321_W_T2_0_Trim Done!
# InkedGVS_322_W_T1_0_Trim Done!
# InkedGVS_322_W_T2_0_Trim Done!
# InkedGVS_323_W_T1_0_Trim Done!
# InkedGVS_323_W_T2_0_Trim Done!
# InkedGVS_310_W_T1_1_Trim Done!
# InkedGVS_310_W_T2_1_Trim Done!
# InkedGVS_311_W_T1_1_Trim Done!
# InkedGVS_311_W_T2_1 Done!
# InkedGVS_312_W_T2_Trim Done!
# InkedGVS_313_W_T1_1_Trim Done!
# InkedGVS_313_W_T2_1_Trim Done!
# InkedGVS_314_W_T1_1_Trim Done!
# InkedGVS_314_W_T2_1_Trim Done!
# InkedGVS_318_W_T1_Trim Done!
# InkedGVS_318_W_T2_Trim Done!
# InkedGVS_320_W_T1_1_Trim Done!
# InkedGVS_320_W_T2_1_Trim Done!
# InkedGVS_321_W_T1_1_Trim Done!
# InkedGVS_321_W_T2_1_Trim Done!
# InkedGVS_322_W_T1_1_Trim Done!
# InkedGVS_322_W_T2_1_Trim Done!
# InkedGVS_323_W_T1_1_Trim Done!
# InkedGVS_323_W_T2_1_Trim Done!
# InkedGVS_403_T_T1_0_Trim Done!
# InkedGVS_403_T_T2_0_Trim Done!
# InkedGVS_406_T_T1_0_Trim Done!
# InkedGVS_406_T_T2_0_Trim Done!
# InkedGVS_407_T_T1_0_Trim Done!
# InkedGVS_407_T_T2_0_Trim Done!
# InkedGVS_408_T_T1_0_Trim Done!
# InkedGVS_408_T_T2_0_Trim Done!
# InkedGVS_410_T_T1_0_Trim Done!
# InkedGVS_410_T_T2_0_Trim Done!
# InkedGVS_403_T_T1_1_Trim Done!
# InkedGVS_403_T_T2_1_Trim Done!
# InkedGVS_406_T_T1_1_Trim Done!
# InkedGVS_406_T_T2_1_Trim Done!
# InkedGVS_407_T_T1_1_Trim Done!
# InkedGVS_407_T_T2_1_Trim Done!
# InkedGVS_408_T_T1_1_Trim Done!
# InkedGVS_408_T_T2_1_Trim Done!
# InkedGVS_409_T_T1_Trim Done!
# InkedGVS_409_T_T2_Trim Done!
# InkedGVS_410_T_T1_1_Trim Done!
# InkedGVS_410_T_T2_1_Trim Done!
# InkedGVS_403_W_T2_0_Trim Done!
# InkedGVS_404_W_T1_0_Trim Done!
# InkedGVS_404_W_T2_0_Trim Done!
# InkedGVS_404_W_T3_0_Trim Done!
# InkedGVS_404_W_T4_0_Trim Done!
# InkedGVS_406_W_T1_0_Trim Done!
# InkedGVS_406_W_T2_0_Trim Done!
# InkedGVS_407_W_T1_0_Trim Done!
# InkedGVS_407_W_T2_0_Trim Done!
# InkedGVS_408_W_T1_0_Trim Done!
# InkedGVS_408_W_T2_0_Trim Done!
# InkedGVS_410_W_T1_0_Trim Done!
# InkedGVS_410_W_T2_0_Trim Done!
# InkedGVS_411_W_T2_0_Trim Done!
# InkedGVS_411_W_T3_0_Trim Done!
# InkedGVS_411_W_T4_0_Trim Done!
# InkedGVS_403_W_T2_1_Trim Done!
# InkedGVS_404_W_T1_1_Trim Done!
# InkedGVS_404_W_T2_1_Trim Done!
# InkedGVS_404_W_T3_1_Trim Done!
# InkedGVS_404_W_T4_1_Trim Done!
# InkedGVS_405_W_T1_Trim Done!
# InkedGVS_405_W_T2_Trim Done!
# InkedGVS_405_W_T3_Trim Done!
# InkedGVS_405_W_T4_Trim Done!
# InkedGVS_406_W_T1_1_Trim Done!
# InkedGVS_406_W_T2_1_Trim Done!
# InkedGVS_407_W_T1_1_Trim Done!
# InkedGVS_407_W_T2_1_Trim Done!
# InkedGVS_408_W_T1_1_Trim Done!
# InkedGVS_408_W_T2_1_Trim Done!
# InkedGVS_409_W_T1_Trim Done!
# InkedGVS_409_W_T2_Trim Done!
# InkedGVS_410_W_T1_1_Trim Done!
# InkedGVS_410_W_T2_1_Trim Done!
# InkedGVS_411_W_T1_1_Trim Done!
# InkedGVS_411_W_T2_1_Trim Done!
# InkedGVS_411_W_T3_1_Trim Done!
# InkedGVS_411_W_T4_1_Trim Done!
# InkedGVS_102_W_T1_1_Trim Done!
# InkedGVS_112_W_T1_1_Trim Done!
# InkedGVS_113_W_T1_1_Trim Done!
# InkedGVS_115_W_T1_1_Trim Done!
# InkedGVS_123_W_T1_1_Trim Done!
# InkedGVS_124_W_T1_1_Trim Done!
# Count of negative x, y and z coordinates are: 0 0 0

# %%
#Sanity Checks!
#Check that x-coordinate is between 0 and 87 cm (width of the treadmill), y coordinate is between 0 and 310 cm 
#(length of the treadmill) and z-coordinate is between 0 and ~120 (maximum length of subject's lower body)
sanity_x, sanity_y, sanity_z = 0, 0, 0
for cohort in cohorts:
    for trial in trials:
        for camera in cameras:
            frame_path = path+cohort+trial+camera #Path to save the frames to 
            if (os.path.exists(frame_path)):
                videos = os.listdir(frame_path)
#             print (len(videos))
            for video in videos:
                frames = glob.glob(frame_path+video+'\\processed3d\\*.csv')
                for frame in frames:
#                     print (frame)
                    frame_csv = pd.read_csv(frame, index_col = 0)
                    sanity_check(frame_csv)
                print (video, 'Done!')
                print ('Sanities (x, y, z in that order) now:', sanity_x, sanity_y, sanity_z)
print ('Count of violating sanity x, y and z coordinates are: ', sanity_x, sanity_y, sanity_z)
# Out:
# InkedGVS_212_T_T1_0_Trim Done!
# Sanities (x, y, z in that order) now: 0 0 0
# InkedGVS
    merged_frame = front_frame.multiply(front_weight, axis=0) + side_frame.multiply(side_weight, axis=0)
    #Simply copy hip and knee coordinates from the front view frame 
    merged_frame[merged_frame.isna()] = front_frame 
    merged_frame= merged_frame.reindex(order)
    return merged_frame

# %%
# order_feet = ['right ankle', 'left ankle', 'left toe 1', 'left toe 2', 'left heel', 'right toe 1', 'right toe 2', \
#          'right heel']

# template = pd.DataFrame(data = 0, index = order_feet, columns = ['x', 'y', 'z', 'confidence'])
# print (template)
# for cohort in cohorts[:3]:
#     for trial in trials:   
#         feet2d_path = path_2d+cohort+trial+'\\feet\\'
#         videos = os.listdir(feet2d_path)
#         for video in videos:
#             print (video)
#             jpg = glob.glob(feet2d_path+video+'\\*.jpg')
#             csv = glob.glob(feet2d_path+video+'\\*.csv')
#             jpg_frames = [x.split('\\')[-1][:-4] for x in jpg]
#             csv_frames = [x.split('\\')[-1][:-4] for x in csv]
#             missing_feet_csv = [x for x in jpg_frames if x not in csv_frames]
#             print (len(missing_feet_csv))
#             for miss in missing_feet_csv:
#                 template.to_csv(path+cohort+trial+'\\feet\\'+video+'\\processed3d\\'+miss+'.csv')
# Out:
#              x  y  z  confidence
# right ankle  0  0  0           0
# left ankle   0  0  0           0
# left toe 1   0  0  0           0
# left toe 2   0  0  0           0
# left heel    0  0  0           0
# right toe 1  0  0  0           0
# right toe 2  0  0  0           0
# right heel   0  0  0           0
# InkedGVS_212_T_T1_0_Trim
# 0
# InkedGVS_212_T_T2_0_Trim
# 0
# InkedGVS_213_T_T1_0_Trim
# 12
# InkedGVS_213_T_T2_0_Trim
# 3
# InkedGVS_214_T_T2_0_Trim
# 809
# InkedGVS_215_T_T1_0_Trim
# 13
# InkedGVS_215_T_T2_0_Trim
# 0
# InkedGVS_216_T_T1_0_Trim
# 1
# InkedGVS_216_T_T2_0_Trim
# 2
# InkedGVS_217_T_T1_0_Trim
# 0
# InkedGVS_217_T_T2_0_Trim
# 0
# InkedGVS_218_T_T1_0_Trim
# 8
# InkedGVS_218_T_T2_0_Trim
# 10
# InkedGVS_219_T_T1_0_Trim
# 0
# InkedGVS_219_T_T2_0_Trim
# 0
# InkedGVS_212_W_T1_0_Trim
# 0
# InkedGVS_212_W_T2_0_Trim
# 0
# InkedGVS_213_W_T1_0_Trim
# 0
# InkedGVS_213_W_T2_0_Trim
# 0
# InkedGVS_214_W_T1_0_Trim
# 0
# InkedGVS_214_W_T2_0_Trim
# 5
# InkedGVS_215_W_T1_0_Trim
# 0
# InkedGVS_215_W_T2_0_Trim
# 3
# InkedGVS_216_W_T1_0_Trim
# 0
# InkedGVS_216_W_T2_0_Trim
# 1
# InkedGVS_217_W_T1_0_Trim
# 0
# InkedGVS_217_W_T2_0_Trim
# 0
# InkedGVS_218_W_T1_0_Trim
# 3
# InkedGVS_218_W_T2_0_Trim
# 0
# InkedGVS_219_W_T1_0_Trim
# 0
# InkedGVS_219_W_T2_0_Trim
# 0
# InkedGVS_310_T_T1_0_Trim
# 5
# InkedGVS_310_T_T2_0_Trim
# 9
# InkedGVS_311_T_T1_0_Trim
# 95
# InkedGVS_311_T_T2_0_Trim
# 48
# InkedGVS_314_T_T1_0_Trim
# 54
# InkedGVS_314_T_T2_0_Trim
# 115
# InkedGVS_320_T_T1_0_Trim
# 0
# InkedGVS_320_T_T2_0_Trim
# 2
# InkedGVS_321_T_T1_0_Trim
# 4
# InkedGVS_321_T_T2_0_Trim
# 10
# InkedGVS_323_T_T1_0_Trim
# 3
# InkedGVS_310_W_T1_0_Trim
# 3
# InkedGVS_310_W_T2_0_Trim
# 0
# InkedGVS_311_W_T1_0_Trim
# 5
# InkedGVS_311_W_T2_0_Trim
# 2
# InkedGVS_313_W_T1_0_Trim
# 40
# InkedGVS_313_W_T2_0_Trim
# 98
# InkedGVS_314_W_T1_0_Trim
# 4
# InkedGVS_314_W_T2_0_Trim
# 2
# InkedGVS_320_W_T1_0_Trim
# 13
# InkedGVS_320_W_T2_0_Trim
# 5
# InkedGVS_321_W_T1_0_Trim
# 0
# InkedGVS_321_W_T2_0_Trim
# 7
# InkedGVS_322_W_T1_0_Trim
# 9
# InkedGVS_322_W_T2_0_Trim
# 15
# InkedGVS_323_W_T1_0_Trim
# 1
# InkedGVS_323_W_T2_0_Trim
# 0
# InkedGVS_403_T_T1_0_Trim
# 22
# InkedGVS_403_T_T2_0_Trim
# 1
# InkedGVS_406_T_T1_0_Trim
# 53
# InkedGVS_406_T_T2_0_Trim
# 36
# InkedGVS_407_T_T1_0_Trim
# 1
# InkedGVS_407_T_T2_0_Trim
# 2
# InkedGVS_408_T_T1_0_Trim
# 6
# InkedGVS_408_T_T2_0_Trim
# 9
# InkedGVS_410_T_T1_0_Trim
# 0
# InkedGVS_410_T_T2_0_Trim
# 0
# InkedGVS_403_W_T2_0_Trim
# 4
# InkedGVS_404_W_T1_0_Trim
# 0
# InkedGVS_404_W_T2_0_Trim
# 0
# InkedGVS_404_W_T3_0_Trim
# 0
# InkedGVS_404_W_T4_0_Trim
# 0
# InkedGVS_406_W_T1_0_Trim
# 6
# InkedGVS_406_W_T2_0_Trim
# 18
# InkedGVS_407_W_T1_0_Trim
# 0
# InkedGVS_407_W_T2_0_Trim
# 0
# InkedGVS_408_W_T1_0_Trim
# 0
# InkedGVS_408_W_T2_0_Trim
# 0
# InkedGVS_410_W_T1_0_Trim
# 0
# InkedGVS_410_W_T2_0_Trim
# 1
# InkedGVS_411_W_T2_0_Trim
# 0
# InkedGVS_411_W_T3_0_Trim
# 1
# InkedGVS_411_W_T4_0_Trim
# 1

# %%
#Example, combine 3D_data\HOA\beam_walking\lower_body\InkedGVS_212_T_T1_1_Trim\processed3d\*.csv and 
#3D_data\HOA\beam_walking\feet\InkedGVS_212_T_T1_0_Trim\processed3d\*.csv to get 
#multi_view_merged_data\HOA\beam_walking\GVS_212_T_T1\*.csv

'''
Combining rules:
1. Combine only the frames that exist in both views (lower body and feet). This eliminates the deleted lower body 
frames that had >8 coordinates missing as being used. Further, this eliminates the possibility of using the 
frames that were trimmed in at least one of the views.
2. If the video doesn't exist in feet, for a video that exists in lower body, simply copy all the lower body frames 
as merged frames.
3. If the video exists in both lower body and feet, then we look for frames that exist in both views and merge them.
4. For merging, simply copy the hip and knee coordinates and weighted average (if value and confidence of left 
ankle's x-coordinate in lower body frame is v_l, c_l and in feet frame is v_f, c_f then merged left ankle's 
x-coordinate is [c_l/(c_l+c_f)]*v_l + [c_f/(c_l+c_f)]*v_f)) for ankle, toes and heel. 
''' 

for cohort in cohorts:
    for trial in trials:   
        merged_path = frame_path_merged+cohort+trial 
        if (os.path.exists(merged_path)):
            videos = os.listdir(merged_path)
            for video in videos:
                print (video)
                front_video = path+cohort+trial+'\\lower_body\\'+'Inked'+video+'_1_Trim'
                side_video = path+cohort+trial+'\\feet\\'+'Inked'+video+'_0_Trim'
                if (os.path.exists(front_video)):
                    print (front_video, 'exists')
                    if (os.path.exists(side_video)): #This is the case when both lower body and feet views exists
                        print (side_video, 'exists')
                        front_frames = os.listdir(front_video+'\\processed3d\\')
                        side_frames = os.listdir(side_video+'\\processed3d\\')
                        #Computing the merged frames only for frames that are common in both views 
                        common_frames = [x for x in front_frames if x in side_frames] 
#                         print (len(front_frames), len(side_frames), len(common_frames))
                        for frame in common_frames:
                            if (not os.path.exists ((merged_path+'\\'+video+'\\'+frame))):
    #                             print (frame)
                                front_frame = pd.read_csv(front_video+'\\processed3d\\'+frame, index_col = 0)
                                side_frame = pd.read_csv(side_video+'\\processed3d\\'+frame, index_col = 0)
    #                             print (front_frame)
    #                             print (side_frame)
                                merged_frame = weighted_average_merge_frame(front_frame, side_frame)
    #                             print (merged_frame)
                                merged_frame.to_csv(merged_path+'\\'+video+'\\'+frame)
                    else: #This is the case when lower body video exists but feet doesn't
                        print (side_video, 'does not exist')
                        print ('Copy')
#                         for file in glob.glob(os.path.join(front_video+'\\processed3d\\', '*.csv*')):
#                             #If only lower body exists, copy all processed 3d files directly to merged files 
#                             shutil.copy(file, merged_path+'\\'+video)
# Out:
# GVS_212_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_212_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_212_T_T1_0_Trim exists
# GVS_212_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_212_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_212_T_T2_0_Trim exists
# GVS_213_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_213_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_213_T_T1_0_Trim exists
# GVS_213_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_213_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_213_T_T2_0_Trim exists
# GVS_214_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_214_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_214_T_T1_0_Trim does not exist
# Copy
# GVS_214_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_214_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_214_T_T2_0_Trim exists
# GVS_215_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_215_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_215_T_T1_0_Trim exists
# GVS_215_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_215_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_215_T_T2_0_Trim exists
# GVS_216_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_216_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_216_T_T1_0_Trim exists
# GVS_216_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_216_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_216_T_T2_0_Trim exists
# GVS_217_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_217_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_217_T_T1_0_Trim exists
# GVS_217_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_217_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_217_T_T2_0_Trim exists
# GVS_218_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_218_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_218_T_T1_0_Trim exists
# GVS_218_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_218_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_218_T_T2_0_Trim exists
# GVS_219_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_219_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_219_T_T1_0_Trim exists
# GVS_219_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\lower_body\InkedGVS_219_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\beam_walking\feet\InkedGVS_219_T_T2_0_Trim exists
# GVS_212_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_212_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_212_W_T1_0_Trim exists
# GVS_212_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_212_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_212_W_T2_0_Trim exists
# GVS_213_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_213_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_213_W_T1_0_Trim exists
# GVS_213_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_213_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_213_W_T2_0_Trim exists
# GVS_214_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_214_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_214_W_T1_0_Trim exists
# GVS_214_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_214_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_214_W_T2_0_Trim exists
# GVS_215_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_215_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_215_W_T1_0_Trim exists
# GVS_215_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_215_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_215_W_T2_0_Trim exists
# GVS_216_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_216_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_216_W_T1_0_Trim exists
# GVS_216_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_216_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_216_W_T2_0_Trim exists
# GVS_217_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_217_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_217_W_T1_0_Trim exists
# GVS_217_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_217_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_217_W_T2_0_Trim exists
# GVS_218_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_218_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_218_W_T1_0_Trim exists
# GVS_218_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_218_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_218_W_T2_0_Trim exists
# GVS_219_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_219_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_219_W_T1_0_Trim exists
# GVS_219_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\lower_body\InkedGVS_219_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\HOA\walking\feet\InkedGVS_219_W_T2_0_Trim exists
# GVS_310_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_310_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_310_T_T1_0_Trim exists
# GVS_310_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_310_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_310_T_T2_0_Trim exists
# GVS_311_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_311_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_311_T_T1_0_Trim exists
# GVS_311_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_311_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_311_T_T2_0_Trim exists
# GVS_312_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_312_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_312_T_T1_0_Trim does not exist
# Copy
# GVS_312_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_312_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_312_T_T2_0_Trim does not exist
# Copy
# GVS_314_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_314_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_314_T_T1_0_Trim exists
# GVS_314_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_314_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_314_T_T2_0_Trim exists
# GVS_318_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_318_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_318_T_T1_0_Trim does not exist
# Copy
# GVS_318_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_318_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_318_T_T2_0_Trim does not exist
# Copy
# GVS_320_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_320_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_320_T_T1_0_Trim exists
# GVS_320_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_320_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_320_T_T2_0_Trim exists
# GVS_321_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_321_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_321_T_T1_0_Trim exists
# GVS_321_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_321_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_321_T_T2_0_Trim exists
# GVS_323_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\lower_body\InkedGVS_323_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\beam_walking\feet\InkedGVS_323_T_T1_0_Trim exists
# GVS_310_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_310_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_310_W_T1_0_Trim exists
# GVS_310_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_310_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_310_W_T2_0_Trim exists
# GVS_311_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_311_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_311_W_T1_0_Trim exists
# GVS_311_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_311_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_311_W_T2_0_Trim exists
# GVS_312_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_312_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_312_W_T2_0_Trim does not exist
# Copy
# GVS_313_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_313_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_313_W_T1_0_Trim exists
# GVS_313_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_313_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_313_W_T2_0_Trim exists
# GVS_314_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_314_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_314_W_T1_0_Trim exists
# GVS_314_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_314_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_314_W_T2_0_Trim exists
# GVS_318_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_318_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_318_W_T1_0_Trim does not exist
# Copy
# GVS_318_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_318_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_318_W_T2_0_Trim does not exist
# Copy
# GVS_320_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_320_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_320_W_T1_0_Trim exists
# GVS_320_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_320_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_320_W_T2_0_Trim exists
# GVS_321_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_321_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_321_W_T1_0_Trim exists
# GVS_321_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_321_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_321_W_T2_0_Trim exists
# GVS_322_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_322_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_322_W_T1_0_Trim exists
# GVS_322_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_322_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_322_W_T2_0_Trim exists
# GVS_323_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_323_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_323_W_T1_0_Trim exists
# GVS_323_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\lower_body\InkedGVS_323_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\MS\walking\feet\InkedGVS_323_W_T2_0_Trim exists
# GVS_403_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_403_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_403_T_T1_0_Trim exists
# GVS_403_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_403_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_403_T_T2_0_Trim exists
# GVS_406_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_406_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_406_T_T1_0_Trim exists
# GVS_406_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_406_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_406_T_T2_0_Trim exists
# GVS_407_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_407_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_407_T_T1_0_Trim exists
# GVS_407_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_407_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_407_T_T2_0_Trim exists
# GVS_408_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_408_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_408_T_T1_0_Trim exists
# GVS_408_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_408_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_408_T_T2_0_Trim exists
# GVS_409_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_409_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_409_T_T1_0_Trim does not exist
# Copy
# GVS_409_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_409_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_409_T_T2_0_Trim does not exist
# Copy
# GVS_410_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_410_T_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_410_T_T1_0_Trim exists
# GVS_410_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\lower_body\InkedGVS_410_T_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\beam_walking\feet\InkedGVS_410_T_T2_0_Trim exists
# GVS_403_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_403_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_403_W_T2_0_Trim exists
# GVS_404_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_404_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_404_W_T1_0_Trim exists
# GVS_404_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_404_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_404_W_T2_0_Trim exists
# GVS_404_W_T3
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_404_W_T3_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_404_W_T3_0_Trim exists
# GVS_404_W_T4
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_404_W_T4_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_404_W_T4_0_Trim exists
# GVS_405_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_405_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_405_W_T1_0_Trim does not exist
# Copy
# GVS_405_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_405_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_405_W_T2_0_Trim does not exist
# Copy
# GVS_405_W_T3
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_405_W_T3_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_405_W_T3_0_Trim does not exist
# Copy
# GVS_405_W_T4
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_405_W_T4_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_405_W_T4_0_Trim does not exist
# Copy
# GVS_406_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_406_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_406_W_T1_0_Trim exists
# GVS_406_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_406_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_406_W_T2_0_Trim exists
# GVS_407_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_407_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_407_W_T1_0_Trim exists
# GVS_407_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_407_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_407_W_T2_0_Trim exists
# GVS_408_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_408_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_408_W_T1_0_Trim exists
# GVS_408_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_408_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_408_W_T2_0_Trim exists
# GVS_409_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_409_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_409_W_T1_0_Trim does not exist
# Copy
# GVS_409_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_409_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_409_W_T2_0_Trim does not exist
# Copy
# GVS_410_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_410_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_410_W_T1_0_Trim exists
# GVS_410_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_410_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_410_W_T2_0_Trim exists
# GVS_411_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_411_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_411_W_T1_0_Trim does not exist
# Copy
# GVS_411_W_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_411_W_T2_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_411_W_T2_0_Trim exists
# GVS_411_W_T3
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_411_W_T3_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_411_W_T3_0_Trim exists
# GVS_411_W_T4
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\lower_body\InkedGVS_411_W_T4_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\PD\walking\feet\InkedGVS_411_W_T4_0_Trim exists
# GVS_102_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\lower_body\InkedGVS_102_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\feet\InkedGVS_102_W_T1_0_Trim does not exist
# Copy
# GVS_112_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\lower_body\InkedGVS_112_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\feet\InkedGVS_112_W_T1_0_Trim does not exist
# Copy
# GVS_113_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\lower_body\InkedGVS_113_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\feet\InkedGVS_113_W_T1_0_Trim does not exist
# Copy
# GVS_115_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\lower_body\InkedGVS_115_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\feet\InkedGVS_115_W_T1_0_Trim does not exist
# Copy
# GVS_123_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\lower_body\InkedGVS_123_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\feet\InkedGVS_123_W_T1_0_Trim does not exist
# Copy
# GVS_124_W_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\lower_body\InkedGVS_124_W_T1_1_Trim exists
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\3D_data\\ExtraHOA\walking\feet\InkedGVS_124_W_T1_0_Trim does not exist
# Copy

# %% [markdown]
# ### Check for missing values (if they exist) after merging and hip height normalization

# %%
#Check if there are any missing values (x, y, z, confidence = 0, 0, 0, 0) in this combined data 
#and how can we treat them before feeding in the models 
#Check any remaining missing values (x, y, z, confidence = 0, 0, 0, 0) after the treatment
def check_missing_values():
    for cohort in cohorts:
        for trial in trials:
            merged_path = frame_path_merged+cohort+trial 
            if (os.path.exists(merged_path)):
                videos = os.listdir(merged_path)
                for video in videos:
                    print (video)
                    counts_missing_frames = 0 #Missing frames in a particular video
                    frames = glob.glob(merged_path+'\\'+video+'\\*.csv')
                    for frame in frames:
    #                     print (frame)
                        frame_csv = pd.read_csv(frame, index_col = 0)
        #                     print (frame_csv)
                        missing = frame_csv[(frame_csv.x==0) & (frame_csv.y==0) & (frame_csv.z==0)] #Missing rows/keypoints in the frame
    #                     print (missing) 
                        len_missing = len(missing)
                        if (len_missing!=0): #No missing values, just update the stats 
                            counts_missing_frames+=1
                            print (frame)
                    print ('Missing values in ', video, 'are:', counts_missing_frames)

check_missing_values()
# Out:
# GVS_212_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T1\33.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T1\34.csv
# Missing values in  GVS_212_T_T1 are: 2
# GVS_212_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\12.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\14.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\231.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\235.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\236.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\326.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\327.csv
# Missing values in  GVS_212_T_T2 are: 7
# GVS_213_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T1\318.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T1\319.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T1\320.csv
# Missing values in  GVS_213_T_T1 are: 3
# GVS_213_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\14.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\815.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\864.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\865.csv
# Missing values in  GVS_213_T_T2 are: 4
# GVS_214_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\12.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\1265.csv
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# KeyboardInterrupt:

# %%
for cohort in cohorts:
    for trial in trials:
        merged_path = frame_path_merged+cohort+trial 
        if (os.path.exists(merged_path)):
            videos = os.listdir(merged_path)
            for video in videos:
                print (video)
                frames = glob.glob(merged_path+'\\'+video+'\\*.csv')
                sorted_frames = sorted(frames,  key=lambda name: int(name.split('\\')[-1][:-4]))
                for idx, frame in enumerate(sorted_frames):
#                     print ('Current frame: ', frame)
                    try:
                        frame_csv = pd.read_csv(frame, index_col = 0)
    #                     print (frame_csv)
                        missing = frame_csv[(frame_csv.x==0) & (frame_csv.y==0) & (frame_csv.z==0)] #Missing rows/keypoints in the frame
    #                     print (missing) 
                        len_missing = len(missing)
                        if (len_missing ==0): #No missing values, just update the stats 
                            pass
                        #If more than or equal to 75% of coordinates are missing, remove the frame
                        elif (len_missing>8): 
                            print(frame, " removed (>8 missing coordinates)!")
                            os.remove(frame)
                        else:
                            for i in range(len_missing):
                                marker = missing.iloc[i]
    #                             print ('Missing marker name', marker.name)
                                frame_csv.loc[marker.name] = missing_value_treatment(sorted_frames, idx, marker.name)
                            frame_csv.to_csv(frame)
                    except Exception as e:
                        print ('Exception!', e)
                print (video, 'DONE!')
# Out:
# GVS_212_T_T1
# GVS_212_T_T1 DONE!
# GVS_212_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\326.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_212_T_T2\326.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\\\HOA\\beam_walking\\GVS_212_T_T2\\326.csv'
# GVS_212_T_T2 DONE!
# GVS_213_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T1\320.csv  removed (>8 missing coordinates)!
# GVS_213_T_T1 DONE!
# GVS_213_T_T2
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\14.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\815.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\864.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_213_T_T2\864.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\\\HOA\\beam_walking\\GVS_213_T_T2\\864.csv'
# GVS_213_T_T2 DONE!
# GVS_214_T_T1
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\12.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\13.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\14.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\15.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\16.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\17.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\19.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\20.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\21.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\22.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\22.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\\\HOA\\beam_walking\\GVS_214_T_T1\\22.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\68.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\1265.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS_214_T_T1\1265.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\\\HOA\\beam_walking\\GVS_214_T_T1\\1265.csv'
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\HOA\beam_walking\GVS
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\120.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\121.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\122.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\123.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\124.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\124.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\\\PD\\walking\\GVS_405_W_T3\\124.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\126.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\127.csv  removed (>8 missing coordinates)!
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\129.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\129.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\\\PD\\walking\\GVS_405_W_T3\\129.csv'
# C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\349.csv  removed (>8 missing coordinates)!
# Exception! [Errno 2] File C:\Users\purpl\Box\Gait Video Project\GaitVideoData\video\multi_view_merged_data\\PD\walking\GVS_405_W_T3\349.csv does not exist: 'C:\\Users\\purpl\\Box\\Gait Video Project\\GaitVideoData\\video\\multi_view_merged_data\\\\PD\\walking\\GVS_405_W_T3\\349.csv'

# %%
check_missing_values()

# %% [markdown]
# ### Hip Height normalization on the merged data

# %%
for cohort in cohorts:
    for trial in trials:
        merged_path = frame_path_merged+cohort+trial 
        if (os.path.exists(merged_path)):
            videos = os.listdir(merged_path)
            for video in videos:
                if os.path.exists(merged_path+'\\'+video+'\\hip_height_normalized'):
                    print (video)

# %%
#After combining, scale all average hip heights to a constant (100 cm) to normalize for subject heights in our dataset
#This is to make sure that we eliminate the effects of size demographics from our dataset 
#Refer http://personal.cityu.edu.hk/meachan/Online%20Anthropometry/Chapter2/Ch2-5.htm
#Refer https://msis.jsc.nasa.gov/sections/section03.htm for estimates of hip heights 
#We use 100 cm as constant hip height for all subjects in our analysis 

#For every .csv in multi_view_merged_data\HOA\beam_walking\GVS_212_T_T1\, we create a new .csv in 
#multi_view_merged_data\HOA\beam_walking\GVS_212_T_T1\hip_height_normalized\, where each file is scaled by 100/avg,
#where avg = [left-hip z-coordinate + right-hip z-coordinate]/2 = average of the left and right hip's height

for cohort in cohorts:
    for trial in trials:
        merged_path = frame_path_merged+cohort+trial 
        if (os.path.exists(merged_path)):
            videos = os.listdir(merged_path)
            for video in videos:
                print (video)
                if not os.path.exists(merged_path+'\\'+video+'\\hip_height_normalized'):
                    os.makedirs(merged_path+'\\'+video+'\\hip_height_normalized')
                frames = glob.glob(merged_path+'\\'+video+'\\*.csv')
                for frame in frames:
#                     print (frame)
                    new_frame_save_path = merged_path+'\\'+video+'\\hip_height_normalized\\'+frame.split('\\')[-1]
                    frame_csv = pd.read_csv(frame, index_col = 0)
                    avg_hip_height = 0.5*(frame_csv.loc['right hip', 'z'] + frame_csv.loc['left hip', 'z'])
                    scaling_factor = const_hip_height/avg_hip_height 
                    #Scaling factor to make sure that when multiplied with average hip height, it scales that to 
                    #100 cm 
                    frame_csv[['x', 'y', 'z']] = scaling_factor*frame_csv[['x', 'y', 'z']] 
                    frame_csv.to_csv(new_frame_save_path)
                print (video, 'Done!')
